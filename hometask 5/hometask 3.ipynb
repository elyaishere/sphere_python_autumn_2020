# %%
from bs4 import BeautifulSoup
import pandas as pd
import re
import requests
import time

# %% [markdown]
# **Этап 1**

# %%
hrefs = []

# %%
root = "https://shop.relod.ru"

# %%
post_url = "https://shop.relod.ru/bitrix/components/bxready.market2/catalog.section/ajax.php"

# %%
data = {
    "siteId": "s1",
    "template": ".default.5066805247fd90f4681c9458759019c47aeeee73c2035d99874d41cd9e7eb382",
    "parameters": "....b41f84069c42bfff0e8e18f2596022ec341f36965c4b377427cabc7844d17928",
    "action": "showMore",
    "PAGEN_1": 1
}

# %%
for i in range(250):
    html_pg = requests.post(post_url, data=data).text
    soup = BeautifulSoup(html_pg, 'lxml')
    divs = soup.find_all('div', attrs={'class':"bxr-element-name"})
    for d in divs:
        hrefs.append(d.find('a').get('href'))
    data["PAGEN_1"] += 1

# %%
len(hrefs)
# Out:
# 5000

# %%
hrefs = list(map(lambda x: root + x, hrefs))

# %% [markdown]
# **Этап 2**

# %%
def get_page(url, n_attempts=5, t_sleep=1, **kwargs):
    for i in range(n_attempts):
        page = requests.get(url)
        if page.status_code == 200:
            return BeautifulSoup(page.text, 'lxml')
        time.sleep(t_sleep)

# %%
def process_page(url):
    book_info = {}
    
    book_info["url"] = url
    
    soup = get_page(url)
    if soup is None:
        return book_info
    
    book_info["Название"] = soup.find('h1').text
    
    table = soup.find_all('tr', attrs={'itemprop':"additionalProperty"})
    for i in table:
        name = i.find('td', attrs={'class':"bxr-props-name"}).text
        val = re.sub(r'\n', '', i.find('td', attrs={'class':"bxr-props-data"}).text)
        book_info[name] = val
    
    marks = list(filter(None, soup.find('div', attrs={'class':"bxr-ribbon-marker-vertical"}).text.split('\n')))
    if len(marks) > 0:
        book_info["Метки"] = marks
    
    img = soup.find('img',  attrs={'itemprop':"image"})
    if img:
        book_info["Иллюстрации"] = ['https:' + img['data-src']]
    
    rate = soup.find('meta',  attrs={'itemprop':"ratingValue"})
    if rate:
        book_info["Оценка"] = float(rate['content'])
    
    cnt = soup.find('meta',  attrs={'itemprop':"ratingCount"})
    if cnt:
        book_info["Число голосов"] = int(cnt['content'])
    
    book_info["Наличие"] = soup.find('div',  attrs={'itemprop':"availability"}).text
    
    price = soup.find('meta', attrs={'itemprop':"price"})
    if price:
        book_info["Цена"] = float(price['content'])
    
    if soup.find('div', attrs={'class':"ptv-block"}):
        scripts = str(soup.find_all('script'))
        book_info["Цена (скидка)"] = float(re.search(r'"PRICE_FORMAT": "(\d+)', scripts).group(1))
    
    book_info["Описание"] = re.sub(r'\s+', ' ',soup.find('div',  attrs={'class':"bxr-detail"}).text)
    
    return book_info

# %%
import sys

# %%
import gzip
import json
import codecs
from tqdm import tqdm

from multiprocessing.dummy import Pool, Queue

queue = Queue()
for href in hrefs:
  queue.put(href)


def process_page_wrapper(i):
    with gzip.open('data/part_{:05d}.jsonl.gz'.format(i), mode='wb') as f_json:
        f_json = codecs.getwriter('utf8')(f_json)

        while not queue.empty():
            url = queue.get()
            try:
                record = process_page(url)
                record_str = json.dumps(record, ensure_ascii=False)
                print(record_str, file=f_json)
            
            except:
                with lock:
                    print("Error log: {url}", file=sys.stderr)

            with lock:
                    pbar.update(1)


with Pool(processes=8) as pool, tqdm(total=queue.qsize()) as pbar:
    lock = pbar.get_lock()
    pool.map(process_page_wrapper, range(pool._processes))
# Out:
# 100%|██████████| 5000/5000 [47:48<00:00,  1.74it/s]

# %% [markdown]
# **Этап 3**

# %%
import os

# %%
import pandas as pd

from itertools import chain         # рекомендуется использовать
from contextlib import ExitStack    # рекомендуется использовать

from typing import Generator, Dict, Any


def records_reader(dirname: str) -> Generator[Dict[str, Any], None, None]:
    base, _, files = next(os.walk(dirname))
    files = [os.path.join(base, f) for f in files if re.match('part_\d{5}.jsonl.gz', f)]
    stack = ExitStack()
    with stack:
        files = [gzip.open(f, mode='rb') for f in files]
        files = chain.from_iterable([stack.enter_context(codecs.getreader('utf8')(f)) for f in files])
        for d in files:
            yield json.loads(d)

df = pd.DataFrame(records_reader('data'))
df.to_csv('hw_3.csv', index=False)

# %%
pd.read_csv('hw_3.csv')
# Out:
#                                                     url  \
# 0     https://shop.relod.ru/catalog-products/the_sil...
# 1     https://shop.relod.ru/catalog-products/the-pil...
# 2     https://shop.relod.ru/catalog-products/zuckerm...
# 3        https://shop.relod.ru/catalog-products/zombie/
# 4     https://shop.relod.ru/catalog-products/zennor_...
# ...                                                 ...
# 4995  https://shop.relod.ru/catalog-products/the_acc...
# 4996  https://shop.relod.ru/catalog-products/the-abc...
# 4997  https://shop.relod.ru/catalog-products/the_120...
# 4998  https://shop.relod.ru/catalog-products/that_lo...
# 4999  https://shop.relod.ru/catalog-products/thankle...
#
#                       Название           ISBN  \
# 0             The Silmarillion  9780261102736
# 1     The Pillars of the Earth  9781509886067
# 2            Zuckerman Unbound  9780099477563
# 3                       Zombie  9780749953379
# 4           Zennor in Darkness  9780141033600
# ...                        ...            ...
# 4995      The Accidental Bride  9780352347626
# 4996  The ABC Murders (Poirot)  9780008308209
# 4997     The 120 Days of Sodom  9780141394343
# 4998       That Loving Feeling  9780751551501
# 4999        Thankless in Death  9780749959388
#
#                                Издатель               Автор     Язык  \
# 0     Harper Collins(сайт издательства)      Tolkien J.R.R.  English
# 1      Pan Macmillan(сайт издательства)         Follett Ken  English
# 2            Vintage(сайт издательства)         Roth Philip  English
# 3            Piatkus(сайт издательства)  Golden Christopher  English
# 4            Penguin(сайт издательства)       Dunmore Helen  English
# ...                                 ...                 ...      ...
# 4995                         Black Lace     Portia Da Costa  English
# 4996  Harper Collins(сайт издательства)     Christie Agatha  English
# 4997         Penguin(сайт издательства)     Marquis de Sade  English
# 4998          Sphere(сайт издательства)     Matthews Carole  English
# 4999    Little Brown(сайт издательства)           Robb J.D.  English
#
#      Возрастные ограничения Рекомендованный возраст     Формат  Страницы  ...  \
# 0                       16+                     16+  Paperback     480.0  ...
# 1                       16+                     16+  Paperback    1104.0  ...
# 2                       16+                     16+  Paperback     240.0  ...
# 3                       16+                     16+  Paperback     512.0  ...
# 4                       16+                     16+  Paperback     320.0  ...
# ...                     ...                     ...        ...       ...  ...
# 4995                    16+                     16+  Paperback     368.0  ...
# 4996                    16+                     16+  Paperback     272.0  ...
# 4997                    16+                     16+  Paperback     464.0  ...
# 4998                    16+                     16+  Paperback     448.0  ...
# 4999                    16+                     16+  Paperback     480.0  ...
#
#         Цена                                           Описание  Серия  \
# 0      678.0  Designed to take fans of The Hobbit and The Lo...    NaN
# 1      774.0  A spellbinding epic tale of ambition, anarchy,...    NaN
# 2      871.0  Following the wild success of his novel, Carno...    NaN
# 3     1113.0  RESURRECTION! The hungry dead have risen. They...    NaN
# 4      871.0  In her prize-winning first novel, Zennor in Da...    NaN
# ...      ...                                                ...    ...
# 4995   989.0  Marrying a billionaire? It's every girl's fant...    NaN
# 4996   763.0  John Malkovich stars as Hercule Poirot in Agat...    NaN
# 4997  1258.0  WINNER OF THE 2017 SCOTT MONCRIEFF PRIZE A new...    NaN
# 4998  1113.0  Juliet Joyce has been happily married to Rick ...    NaN
# 4999   259.0  He looked at his hands, covered with her blood...    NaN
#
#          Метки Цена (скидка) Читательская аудитория  Носитель  Тип продукта  \
# 0          NaN           NaN                    NaN       NaN           NaN
# 1          NaN           NaN                    NaN       NaN           NaN
# 2          NaN           NaN                    NaN       NaN           NaN
# 3          NaN           NaN                    NaN       NaN           NaN
# 4          NaN           NaN                    NaN       NaN           NaN
# ...        ...           ...                    ...       ...           ...
# 4995       NaN           NaN                    NaN       NaN           NaN
# 4996       NaN           NaN                    NaN       NaN           NaN
# 4997       NaN           NaN                    NaN       NaN           NaN
# 4998       NaN           NaN                    NaN       NaN           NaN
# 4999  ['Sale']           NaN                    NaN       NaN           NaN
#
#      Издание  Обзор/Ролик
# 0        NaN          NaN
# 1        NaN          NaN
# 2        NaN          NaN
# 3        NaN          NaN
# 4        NaN          NaN
# ...      ...          ...
# 4995     NaN          NaN
# 4996     NaN          NaN
# 4997     NaN          NaN
# 4998     NaN          NaN
# 4999     NaN          NaN
#
# [5000 rows x 29 columns]
